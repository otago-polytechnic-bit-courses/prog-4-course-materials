# %% [markdown]
# ##### College of Engineering, Construction and Living Sciences<br>Bachelor of Information Technology<br>IN628: Programming 4<br>Level 6, Credits 15<br><br>Deadline: Friday, 12 June at 5pm
#
# # Practical 21: Builder Pattern
#
# In this practical, you will complete a series of tasks covering today's lecture. This practical is worth 1% of the final mark for the Programming 4 course.

# %%
# %config IPCompleter.greedy=True

# %% [markdown]
# ## Builder Pattern

# %% [markdown]
# ### Building A House
# **Task 1:**
# 1. Create an abstract class called `Builder` with an `@abstractproperty` called `product` & the following methods:
#     - `set_num_rooms(self, num_rooms)` - `num_rooms` is an int value
#     - `set_num_doors(self, num_doors)` - `num_doors` is an int value
#     - `set_num_windows(self, num_windows)` - `num_windows` is an int value
#     - `set_has_garage(self, has_garage)` - `has_garage` is a bool value
#     - `set_has_garden(self, has_garden)` - `has_garden` is a bool value
#     - `set_has_swimming_pool(self, has_swimming_pool)` - `has_swimming_pool` is a bool value
# 2. Use the hints provided to display the expected output

# %%
from abc import ABC, abstractmethod, abstractproperty


# Write your Builder class solution here


class HouseBuilder(Builder):
    def __init__(self):
        # Call the reset method

    def reset(self):
        self.__product =  # House object

    @property
    def product(self):
        product = self.__product
        # Call the reset method
        return product

    def set_num_rooms(self, num_rooms):
        self.__product.add()  # Add a string displaying the number of rooms to product

    def set_num_doors(self, num_doors):
        self.__product.add()  # Add a string displaying the number of doors to product

    def set_num_windows(self, num_windows):
        self.__product.add()  # Add a string displaying the number of windows to product

    def set_has_garage(self, has_garage):
        self.__product.add()  # Add a string displaying the house has a garage to product

    def set_has_garden(self, has_garden):
        self.__product.add()  # Add a string displaying the house has a garden to product

    def set_has_swimming_pool(self, has_swimming_pool):
        self.__product.add()  # Add a string displaying the house a swimming pool to product


class House:
    def __init__(self):
        self.details =  # Empty list

    def add(self, detail):
        self.details.append(detail)

    def display_details(self):
        # Loop through each item in details
            # Display item


class Director:
    def __init__(self):
        self.__builder = None

    @property
    def builder(self):
        return self.__builder

    @builder.setter
    def builder(self, builder):
        self.__builder = builder

    def build_house_details(self):
        # Call HouseBuilder methods


def main():
    director = Director()
    house_builder = HouseBuilder()
    director.builder = house_builder

    print('House details:')
    director.build_house_details()
    house_builder.product.display_details()


if __name__ == '__main__':
    main()

    # Expected output:

    # House details:
    # Number of rooms: 5
    # Number of doors: 15
    # Number of windows: 30
    # Has a garage: True
    # Has a garden: True
    # Has a swimming pool: False

# %% [markdown]
# ### Ordering A Pizza
# **Task 2:** Consider the following program skeleton. Use the hints provided to display the expected output.
#
# Resource - https://docs.python.org/3/library/enum.html

# %%
from abc import ABC, abstractmethod, abstractproperty
from enum import Enum
from time import sleep


class Progress(Enum):
    ORDER_PLACED = 'order placed'
    PREPARING = 'preparing'
    COOKING = 'cooking'
    READY = 'ready'


class Dough(Enum):
    THIN_CRUST = 'thin crust'
    THICK_CRUST = 'thick crust'


class Sauce(Enum):
    TOMATO = 'tomato'
    BBQ = 'bbq'


class Topping(Enum):
    HAM = 'ham'
    MOZZARELLA = 'mozzarella'
    MUSHROOMS = 'mushrooms'
    BACON = 'bacon'
    OREGANO = 'oregano'


class Builder(ABC):
    @abstractproperty
    def product(self):
        pass

    @abstractmethod
    def set_order(self, progress_name):
        pass

    @abstractmethod
    def set_dough(self, progress_name, progress_val, dough_val):
        pass

    @abstractmethod
    def set_sauce(self, progress_name, sauce_val):
        pass

    @abstractmethod
    def set_topping(self, progress_name, topping_val):
        pass

    @abstractmethod
    def set_cooking(self, progress_name, progress_val):
        pass

    @abstractmethod
    def set_ready(self, progress_name, progress_val):
        pass


class PizzaBuilder(Builder):
    def __init__(self):
        # Call the reset method

    def reset(self):
        self.__product =  # Pizza object

    @property
    def product(self):
        product = self.__product
        # Call the reset method
        return product

    def set_order(self, progress_name):
        # Add a string displaying the progress name to product

    def set_dough(self, progress_name, progress_val, dough_val):
        # Add a string displaying the progress name, progress value & dough value to product

    def set_sauce(self, progress_name, sauce_val):
        # Add a string displaying the progress name & sauce value to product

    def set_topping(self, progress_name, topping_val):
        # Add a string displaying the progress name & topping value to product

    def set_cooking(self, progress_name, progress_val):
        # Add a string displaying the progress name & progress value to product

    def set_ready(self, progress_name, progress_val):
        # Add a string displaying the progress name & progress value to product


class Pizza:
    def __init__(self):
        self.details =  # Empty list

    def add(self, detail):
        self.details.append(detail)

    def display_details(self):
        # Loop through each item in details
            # Sleep every 2.5 seconds
            # Display item


class Director:
    def __init__(self):
        self.__builder = None

    @property
    def builder(self):
        return self.__builder

    @builder.setter
    def builder(self, builder):
        self.__builder = builder

    def build_pizza_details(self):
        toppings = [Topping.MOZZARELLA.value,
                    Topping.MUSHROOMS.value, Topping.OREGANO.value]
        progress_prep = Progress.PREPARING
        self.builder.set_order(Progress.ORDER_PLACED.name)
        self.builder.set_dough(
            progress_prep.name, progress_prep.value, Dough.THICK_CRUST.value)
        self.builder.set_sauce(progress_prep.name, Sauce.TOMATO.value)
        self.builder.set_topping(progress_prep.name, ', '.join(toppings))
        self.builder.set_cooking(Progress.COOKING.name, Progress.COOKING.value)
        self.builder.set_ready(Progress.READY.name, Progress.READY.value)


def main():
    director = Director()
    pizza_builder = PizzaBuilder()
    director.builder = pizza_builder

    print('Pizza order details:')
    director.build_pizza_details()
    pizza_builder.product.display_details()


if __name__ == '__main__':
    main()

    # Expected output:

    # Pizza order details:
    # Current progress: ORDER_PLACED - your pizza order was succesfully placed
    # Current progress: PREPARING - preparing thick crust dough for your pizza
    # Current progress: PREPARING - adding tomato sauce to your pizza
    # Current progress: PREPARING - adding mozzarella, mushrooms, oregano toppings to your pizza
    # Current progress: COOKING - cooking your pizza
    # Current progress: READY - your pizza is ready

# %% [markdown]
# # Submission
# 1. Create a new branch named 21-checkpoint within your practicals GitHub repository
# 2. Create a new pull request and assign Grayson-Orr to review your submission
#
# **Note:** Please don't merge your own pull request.
